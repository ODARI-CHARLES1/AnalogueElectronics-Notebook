# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from control import matlab as m
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# $T(s)=\frac{s^2+s+100} {s^3+25s^2}$

# %%
num=[1,1,100];
den=[1,25,1,0];
sys=m.tf(num,den)

# %%
#Bode plot
mag,phase,omega=m.bode(sys)
